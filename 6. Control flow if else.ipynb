# %% [markdown]
# ## Python if... else Statement
#
# The **if...elif...else** statement is used in Python for decision making.
#
#
# ### if statement syntax:
#
#     if test expression:
#         statement(s)
#
#
# **Note:** The program evaluates the test expression and will execute statement(s) only if the text expression is True.
# If the text expression is False, the statement(s) is not executed.
#
# Python interprets non-zero values as True. None and 0 are interpreted as False.

# %% [markdown]
# ![Python_if_statement.jpg](attachment:Python_if_statement.jpg)

# %%
num = 10 

# try 0, -1 and None
if num > 10:
    print("The number is positive")

print("This will print always")
# Out:
# This will print always

# %%
num = 10 

# try 0, -1 and None
if num == 10:
    print("The number is positive")

print("This will print always")
# Out:
# The number is positive
# This will print always

# %%
num = 10 

# try 0, -1 and None
if num - 10:
    print("The number is positive")

print("This will print always")
# Out:
# This will print always

# %%
num = -1

# try 0, -1 and None
if num == -1:
    print("The number is positive")

print("This will print always")
# Out:
# The number is positive
# This will print always

# %%
# try 0, -1 and None
if None:
    print("The number is positive")

print("This will print always")
# Out:
# This will print always

# %% [markdown]
# ### if ... else Statement
#
# ![Python_if_else_statement.jpg](attachment:Python_if_else_statement.jpg)

# %%
num = 10 

if num > 0:
    print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %% [markdown]
# ### if...elif...else Statement
#
# ![Python_if_elif_else_statement.jpg](attachment:Python_if_elif_else_statement.jpg)

# %%
num = 10.5 

if num > 0:
    print("Positive Number")
elif num == 0:
    print("Zero")
else:
    print("Negative Number")
# Out:
# Positive Number

# %%
num = 0 

if num > 0:
    print("Positive Number")
elif num == 0:
    print("Zero")
else:
    print("Negative Number")
# Out:
# Zero

# %% [markdown]
# ### Nested if Statements

# %%
num = 10.5

if num >=0:
    if num == 0:
        print("Zero")
    else:
        print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %%
num = 0

if num >=0:
    if num == 0:
        print("Zero")
    else:
        print("Positive Number")
else:
    print("Negative Number")
# Out:
# Zero

# %% [markdown]
# ### Python program to find the largest element among three numbers.

# %%
num1 = 10
num2 = 50
num3 = 15


if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
    
print("Largest element among three numbers is: {}".format(largest))
# Out:
# Largest element among three numbers is: 50

# %%
num1 = 10
num2 = 10
num3 = 10


if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
    
print("Largest element among three numbers is: {}".format(largest))
# Out:
# Largest element among three numbers is: 10
